# %%
# %run ../includes/common-20230414.ipynb
# Out:
# CPython 2024-01-15T08:21:01.229226
# <style>.container { width:100% !important; }</style>
# CPU times: user 333 µs, sys: 178 µs, total: 511 µs
# Wall time: 523 µs

# %%
dfc_raw = get_df()

# %%
dfs_01 = get_data(dfc_raw, default_sample_ratio=.1, verbose=2, skipna=True)
# Out:
# 9065
#                                              P100ServiceTimeUtil@10m
# Region                                                       Region1   Region2    Region3    Region4    Region5    Region6    Region7
# AdmissionPolicyLabel Prefetching
# Baleen               All on Partial Hit                    19.834400  6.425599  11.654867  54.879056  33.377278  38.872473  38.317827
#                      ML-Range on Every Miss                      NaN       NaN        NaN  65.046881  37.496542  42.184904  42.334238
#                      ML-Range on ML-When                   18.798724  6.808306   7.240523  63.198452  35.002640  40.142733  37.209329
#                      ML-Range on Partial Hit                     NaN  6.414942   9.071753  56.316178  33.372318  39.122878  38.353781
#                      No prefetching                        22.615142  7.612986   7.409684  64.558061  37.165466  42.442340  39.476593
# CoinFlip             All on Partial Hit                    23.749497  7.880786   9.954943  65.488021  38.752265  44.108429  46.148613
#                      No prefetching                        23.833461  9.070086   7.618750  67.828619  41.455241  46.460220  46.115390
# RejectX              All on Partial Hit                    23.001399  8.204061   9.417311  54.489408  35.519260  40.770646  40.897261
#                      No prefetching                        22.860858  9.057745   9.253684  66.072516  35.512876  40.844129  39.081207
# /tmp/ipykernel_7144/3317348687.py:14: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   best_pf_option_ = best_pf_option.idxmin(skipna=skipna)
#                      P100ServiceTimeUtil@10m
# Region                               Region1   Region2   Region3    Region4    Region5    Region6    Region7
# AdmissionPolicyLabel
# Baleen                             18.798724  6.414942  7.240523  54.879056  33.372318  38.872473  37.209329
# CoinFlip                           23.749497  7.880786  7.618750  65.488021  38.752265  44.108429  46.115390
# RejectX                            22.860858  8.204061  9.253684  54.489408  35.512876  40.770646  39.081207
#                      P100ServiceTimeUtil@10m
# Region                               Region1                  Region2              Region3             Region4                  Region5             Region6              Region7
# AdmissionPolicyLabel
# Baleen                   ML-Range on ML-When  ML-Range on Partial Hit  ML-Range on ML-When  All on Partial Hit  ML-Range on Partial Hit  All on Partial Hit  ML-Range on ML-When
# CoinFlip                  All on Partial Hit       All on Partial Hit       No prefetching  All on Partial Hit       All on Partial Hit  All on Partial Hit       No prefetching
# RejectX                       No prefetching       All on Partial Hit       No prefetching  All on Partial Hit           No prefetching  All on Partial Hit       No prefetching
#                                              P100ServiceTimeUtil@10m
# Region                                                       Region1                                     Region2                                             Region3                                    Region4                                                                      Region5                                                                                                       Region6                                                                                                       Region7
# Target DWPD                                                    1.00       7.50       15.00      20.00      1.00       3.75      7.50      15.00     20.00      1.00       3.00      3.75       7.50       1.00       3.00       3.75       7.50       12.50      15.00      20.00      1.00       2.50       3.00       3.75       7.50       10.00      12.50      15.00      17.50      20.00      1.00       2.50       3.00       3.75       7.50       10.00      12.50      15.00      17.50      20.00      1.00       2.50       3.00       3.75       7.50       10.00      12.50      15.00      17.50      20.00
# AdmissionPolicyLabel Prefetching
# Baleen               All on Partial Hit                    26.028035  19.834400  20.343761  20.436503   8.327849   6.939808  6.425599  6.837110  7.112665   9.398031  11.811845       NaN  11.654867  75.121155        NaN  62.854418  54.879056  47.910569  44.728773  46.782943  62.373242        NaN        NaN  33.657535  33.377278        NaN        NaN  32.680641        NaN  32.517173  72.686623        NaN        NaN  41.566890  38.872473        NaN        NaN  37.660015        NaN  37.688814  64.401850        NaN        NaN  42.813332  38.317827        NaN        NaN  37.396343        NaN  37.391811
#                      ML-Range on Every Miss                      NaN        NaN        NaN        NaN        NaN        NaN       NaN       NaN       NaN        NaN        NaN       NaN        NaN        NaN        NaN        NaN  65.046881  65.350089        NaN        NaN        NaN        NaN        NaN        NaN  37.496542        NaN  37.156404        NaN        NaN        NaN        NaN        NaN        NaN        NaN  42.184904        NaN  42.070735        NaN        NaN        NaN        NaN        NaN        NaN        NaN  42.334238        NaN  41.961296        NaN        NaN        NaN
#                      ML-Range on ML-When                   25.678069  18.798724  18.466428  18.475093   8.308623   6.897277  6.808306  6.428405  6.437252   9.169884   8.546153       NaN   7.240523  74.411560        NaN  65.452060  63.198452  62.397416  63.687802  63.612404  45.359232        NaN        NaN  35.635111  35.002640        NaN        NaN  33.769219        NaN  33.339318  65.322713        NaN        NaN  42.738954  40.142733        NaN        NaN  38.282581        NaN  38.038160  59.018569        NaN        NaN  40.049511  37.209329        NaN        NaN  35.999039        NaN  36.563237
#                      ML-Range on Partial Hit                     NaN        NaN        NaN        NaN   8.292691   6.921898  6.414942  6.825587  7.072145   9.293920        NaN  9.439623   9.071753  75.545932  65.567639  64.826636  56.316178  45.762035  44.814266        NaN  54.207490        NaN  36.505447  35.340411  33.372318        NaN  31.856944  31.665668        NaN        NaN  55.105266        NaN  43.017105  43.204902  39.122878        NaN  37.052901  36.310998        NaN        NaN  62.724994        NaN  41.170924  40.461458  38.353781        NaN  37.785512  37.378064        NaN        NaN
#                      No prefetching                        31.844107  22.615142  22.109465  22.330746   8.353005   7.688987  7.612986  7.788980  8.203647   9.166841   7.728422       NaN   7.409684  72.033226        NaN  65.762493  64.558061  63.486388  63.194288  61.407744  42.492089        NaN        NaN  36.459944  37.165466        NaN        NaN  36.969852        NaN  36.725246  50.383398        NaN        NaN  43.510410  42.442340        NaN        NaN  40.998809        NaN  41.363363  60.487060        NaN        NaN  40.617382  39.476593        NaN        NaN  40.196934        NaN  39.218880
# CoinFlip             All on Partial Hit                    36.059240  23.749497  23.165936  22.991357  12.737140   9.264273  7.880786  6.857150  6.878319  10.437036   9.188024       NaN   9.954943  79.307834        NaN  71.142384  65.488021  60.608944  58.592060  53.332376        NaN  47.936584        NaN  45.498854  38.752265  37.128811  36.457707        NaN  35.286653  34.882127        NaN  52.419739        NaN  48.942884  44.108429  42.484656  41.023682        NaN  40.022412  39.649845        NaN  51.860164        NaN  48.688092  46.148613  44.190341  42.479817        NaN  41.513792  40.884802
#                      No prefetching                        37.868485  23.833461  23.344520  23.218959  13.450607  10.533974  9.070086  7.952956  8.073352  10.690234   9.548977       NaN   7.618750  79.028463        NaN  71.394655  67.828619  66.155172  66.177151  65.680667  57.507281  48.299913        NaN  45.501624  41.455241  39.990705  39.360622  39.900134  38.063007  38.117130  55.256846  51.950889        NaN  48.799631  46.460220  45.124940  44.569080  44.995887  43.072379  43.129216  63.744362  52.795620        NaN  49.367941  46.115390  44.779589  44.228990  43.350005  43.234573  42.670531
# RejectX              All on Partial Hit                    24.663729  23.001399  22.623932  22.506218   8.325851   7.762990  8.204061       NaN       NaN   9.376388   9.199176       NaN   9.417311  76.408321        NaN  66.175635  54.489408  41.720584  41.004191  40.122775        NaN  45.892492        NaN  42.472857  35.519260  34.474259  34.484947        NaN  33.303344  33.144995        NaN  59.702106        NaN  48.120527  40.770646  39.155836  38.502818        NaN  37.055468  36.803804        NaN  61.389970        NaN  59.020947  40.897261  38.330719  37.477974        NaN  36.674255  36.447021
#                      No prefetching                        23.871831  22.860858  22.574118  22.436545   9.306058   8.506238  9.057745       NaN       NaN   9.729085   9.099073       NaN   9.253684  71.475271        NaN  66.934034  66.072516  65.349316  65.311165  65.699328        NaN  42.214323        NaN  39.953338  35.512876  35.179005  34.569137  35.092916  34.043852  34.301925        NaN  46.522174        NaN  42.200881  40.844129  39.497591  38.592601  38.884347  38.107477  38.407547        NaN  58.415048        NaN  42.102425  39.081207  38.610111  38.242740  38.262191  37.760481  37.691571
# /tmp/ipykernel_7144/3317348687.py:14: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   best_pf_option_ = best_pf_option.idxmin(skipna=skipna)
#                      P100ServiceTimeUtil@10m
# Region                               Region1                                     Region2                                            Region3                                  Region4                                                                      Region5                                                                                                       Region6                                                                                                       Region7
# Target DWPD                              1.0        7.5       15.0       20.0        1.0      3.75       7.5      15.0      20.0        1.0       3.0      3.75       7.5        1.0        3.0       3.75        7.5       12.5       15.0       20.0        1.0        2.5        3.0       3.75        7.5       10.0       12.5       15.0       17.5       20.0        1.0        2.5        3.0       3.75        7.5       10.0       12.5       15.0       17.5       20.0        1.0        2.5        3.0       3.75        7.5       10.0       12.5       15.0       17.5       20.0
# AdmissionPolicyLabel
# Baleen                             25.678069  18.798724  18.466428  18.475093   8.292691  6.897277  6.414942  6.428405  6.437252   9.166841  7.728422  9.439623  7.240523  72.033226  65.567639  62.854418  54.879056  45.762035  44.728773  46.782943  42.492089        NaN  36.505447  33.657535  33.372318        NaN  31.856944  31.665668        NaN  32.517173  50.383398        NaN  43.017105  41.566890  38.872473        NaN  37.052901  36.310998        NaN  37.688814  59.018569        NaN  41.170924  40.049511  37.209329        NaN  37.785512  35.999039        NaN  36.563237
# CoinFlip                           36.059240  23.749497  23.165936  22.991357  12.737140  9.264273  7.880786  6.857150  6.878319  10.437036  9.188024       NaN  7.618750  79.028463        NaN  71.142384  65.488021  60.608944  58.592060  53.332376  57.507281  47.936584        NaN  45.498854  38.752265  37.128811  36.457707  39.900134  35.286653  34.882127  55.256846  51.950889        NaN  48.799631  44.108429  42.484656  41.023682  44.995887  40.022412  39.649845  63.744362  51.860164        NaN  48.688092  46.115390  44.190341  42.479817  43.350005  41.513792  40.884802
# RejectX                            23.871831  22.860858  22.574118  22.436545   8.325851  7.762990  8.204061       NaN       NaN   9.376388  9.099073       NaN  9.253684  71.475271        NaN  66.175635  54.489408  41.720584  41.004191  40.122775        NaN  42.214323        NaN  39.953338  35.512876  34.474259  34.484947  35.092916  33.303344  33.144995        NaN  46.522174        NaN  42.200881  40.770646  39.155836  38.502818  38.884347  37.055468  36.803804        NaN  58.415048        NaN  42.102425  39.081207  38.330719  37.477974  38.262191  36.674255  36.447021
#                      P100ServiceTimeUtil@10m                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             \
# Region                               Region1                                                                                 Region2                                                                                                     Region3                                                                           Region4                                                                                                                                           Region5                                                                                                                                                                                                                 Region6                                                                                                                                                                                                             Region7
# Target DWPD                              1.0                  7.5                 15.0                 20.0                      1.0                 3.75                      7.5                 15.0                 20.0                 1.0                 3.0                     3.75                  7.5             1.0                      3.0                3.75                 7.5                     12.5                15.0                20.0             1.0                 2.5                      3.0                3.75                      7.5                10.0                     12.5                     15.0                17.5                20.0             1.0             2.5                      3.0                3.75                 7.5                10.0                     12.5                     15.0                17.5                20.0                  1.0                 2.5                      3.0                 3.75                  7.5
# AdmissionPolicyLabel
# Baleen                   ML-Range on ML-When  ML-Range on ML-When  ML-Range on ML-When  ML-Range on ML-When  ML-Range on Partial Hit  ML-Range on ML-When  ML-Range on Partial Hit  ML-Range on ML-When  ML-Range on ML-When      No prefetching      No prefetching  ML-Range on Partial Hit  ML-Range on ML-When  No prefetching  ML-Range on Partial Hit  All on Partial Hit  All on Partial Hit  ML-Range on Partial Hit  All on Partial Hit  All on Partial Hit  No prefetching                 NaN  ML-Range on Partial Hit  All on Partial Hit  ML-Range on Partial Hit                 NaN  ML-Range on Partial Hit  ML-Range on Partial Hit                 NaN  All on Partial Hit  No prefetching             NaN  ML-Range on Partial Hit  All on Partial Hit  All on Partial Hit                 NaN  ML-Range on Partial Hit  ML-Range on Partial Hit                 NaN  All on Partial Hit  ML-Range on ML-When                 NaN  ML-Range on Partial Hit  ML-Range on ML-When  ML-Range on ML-When
# CoinFlip                  All on Partial Hit   All on Partial Hit   All on Partial Hit   All on Partial Hit       All on Partial Hit   All on Partial Hit       All on Partial Hit   All on Partial Hit   All on Partial Hit  All on Partial Hit  All on Partial Hit                      NaN       No prefetching  No prefetching                      NaN  All on Partial Hit  All on Partial Hit       All on Partial Hit  All on Partial Hit  All on Partial Hit  No prefetching  All on Partial Hit                      NaN  All on Partial Hit       All on Partial Hit  All on Partial Hit       All on Partial Hit           No prefetching  All on Partial Hit  All on Partial Hit  No prefetching  No prefetching                      NaN      No prefetching  All on Partial Hit  All on Partial Hit       All on Partial Hit           No prefetching  All on Partial Hit  All on Partial Hit       No prefetching  All on Partial Hit                      NaN   All on Partial Hit       No prefetching
# RejectX                       No prefetching       No prefetching       No prefetching       No prefetching       All on Partial Hit   All on Partial Hit       All on Partial Hit                  NaN                  NaN  All on Partial Hit      No prefetching                      NaN       No prefetching  No prefetching                      NaN  All on Partial Hit  All on Partial Hit       All on Partial Hit  All on Partial Hit  All on Partial Hit             NaN      No prefetching                      NaN      No prefetching           No prefetching  All on Partial Hit       All on Partial Hit           No prefetching  All on Partial Hit  All on Partial Hit             NaN  No prefetching                      NaN      No prefetching  All on Partial Hit  All on Partial Hit       All on Partial Hit           No prefetching  All on Partial Hit  All on Partial Hit                  NaN      No prefetching                      NaN       No prefetching       No prefetching
#
#
# Region
# Target DWPD                         10.0                     12.5                 15.0                17.5                 20.0
# AdmissionPolicyLabel
# Baleen                               NaN  ML-Range on Partial Hit  ML-Range on ML-When                 NaN  ML-Range on ML-When
# CoinFlip              All on Partial Hit       All on Partial Hit       No prefetching  All on Partial Hit   All on Partial Hit
# RejectX               All on Partial Hit       All on Partial Hit       No prefetching  All on Partial Hit   All on Partial Hit

# %%
df_01f = sampleright(dfs_01['exp34_canon'], idx=['ShortLabel', 'Target Write Rate', 'Target DWPD'])

# %%
y = 'P100ServiceTimeUtil@10m'

# %%
d1a, d1r = stats(df_01f, y=y, agg='RegionLabel', verbose=2)
y2 = 'P50ServiceTimeUtil@10m'
d1a_50, d1r_50 = stats(df_01f, y=y2, agg='RegionLabel', verbose=2)
latex_macros({
    'PeakSavingsOverNoCachingPercent': d1a[y].loc["Baleen", "Avg"],
    'PeakSavingsOverRejectxPercent': d1r[y].loc["RejectX", "Avg"],
    'PeakSavingsOverCoinflipPercent': d1r[y].loc["CoinFlip", "Avg"],
    'PeakSavingsOverRejectxPercentMin': d1r[y].loc["RejectX"].min(),
    'PeakSavingsOverRejectxPercentMax': d1r[y].loc["RejectX"].max(),
    'MedianSavingsOverRejectxPercent': d1r_50[y2].loc["RejectX", "Avg"],
    'MedianSavingsOverCoinflipPercent': d1r_50[y2].loc["RejectX", "Avg"],
})
# Out:
# Raw
#                      P100ServiceTimeUtil@10m
# RegionLabel                          Region1 Region2 Region3 Region4 Region5 Region6 Region7   Avg
# ShortLabel
# Baleen                                 18.80    6.41    7.24   54.88   33.37   38.87   37.21 28.11
# Baleen (No Prefetch)                   22.62    7.61    7.41   64.56   37.17   42.44   39.48 31.61
# CoinFlip                               23.83    9.07    7.62   67.83   41.46   46.46   46.12 34.63
# RejectX                                22.86    9.06    9.25   66.07   36.48   40.84   39.08 31.95
# Savings over Baleen
# <style type="text/css">
# #T_c4cea_row0_col0, #T_c4cea_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 33.1%, green 33.1%, green 50.0%, transparent 50.0%);
# }
# #T_c4cea_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 34.3%, green 34.3%, green 50.0%, transparent 50.0%);
# }
# #T_c4cea_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 47.7%, green 47.7%, green 50.0%, transparent 50.0%);
# }
# #T_c4cea_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 35.0%, green 35.0%, green 50.0%, transparent 50.0%);
# }
# #T_c4cea_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 39.8%, green 39.8%, green 50.0%, transparent 50.0%);
# }
# #T_c4cea_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 41.6%, green 41.6%, green 50.0%, transparent 50.0%);
# }
# #T_c4cea_row0_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.3%, green 44.3%, green 50.0%, transparent 50.0%);
# }
# #T_c4cea_row0_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 38.9%, green 38.9%, green 50.0%, transparent 50.0%);
# }
# #T_c4cea_row0_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 39.4%, green 39.4%, green 50.0%, transparent 50.0%);
# }
# #T_c4cea_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 28.9%, green 28.9%, green 50.0%, transparent 50.0%);
# }
# #T_c4cea_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.7%, green 20.7%, green 50.0%, transparent 50.0%);
# }
# #T_c4cea_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 45.0%, green 45.0%, green 50.0%, transparent 50.0%);
# }
# #T_c4cea_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 30.9%, green 30.9%, green 50.0%, transparent 50.0%);
# }
# #T_c4cea_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 30.5%, green 30.5%, green 50.0%, transparent 50.0%);
# }
# #T_c4cea_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 33.7%, green 33.7%, green 50.0%, transparent 50.0%);
# }
# #T_c4cea_row1_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 30.7%, green 30.7%, green 50.0%, transparent 50.0%);
# }
# #T_c4cea_row1_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 31.2%, green 31.2%, green 50.0%, transparent 50.0%);
# }
# #T_c4cea_row1_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 31.5%, green 31.5%, green 50.0%, transparent 50.0%);
# }
# #T_c4cea_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 32.2%, green 32.2%, green 50.0%, transparent 50.0%);
# }
# #T_c4cea_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.8%, green 20.8%, green 50.0%, transparent 50.0%);
# }
# #T_c4cea_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 28.2%, green 28.2%, green 50.0%, transparent 50.0%);
# }
# #T_c4cea_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 41.5%, green 41.5%, green 50.0%, transparent 50.0%);
# }
# #T_c4cea_row2_col5, #T_c4cea_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 45.2%, green 45.2%, green 50.0%, transparent 50.0%);
# }
# #T_c4cea_row2_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 38.0%, green 38.0%, green 50.0%, transparent 50.0%);
# }
# #T_c4cea_row2_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 35.2%, green 35.2%, green 50.0%, transparent 50.0%);
# }
# </style>
# <table id="T_c4cea">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c4cea_level0_col0" class="col_heading level0 col0" colspan="9">P100ServiceTimeUtil@10m</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >RegionLabel</th>
#       <th id="T_c4cea_level1_col0" class="col_heading level1 col0" >Region1</th>
#       <th id="T_c4cea_level1_col1" class="col_heading level1 col1" >Region2</th>
#       <th id="T_c4cea_level1_col2" class="col_heading level1 col2" >Region3</th>
#       <th id="T_c4cea_level1_col3" class="col_heading level1 col3" >Region4</th>
#       <th id="T_c4cea_level1_col4" class="col_heading level1 col4" >Region5</th>
#       <th id="T_c4cea_level1_col5" class="col_heading level1 col5" >Region6</th>
#       <th id="T_c4cea_level1_col6" class="col_heading level1 col6" >Region7</th>
#       <th id="T_c4cea_level1_col7" class="col_heading level1 col7" >Avg</th>
#       <th id="T_c4cea_level1_col8" class="col_heading level1 col8" >Avg%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ShortLabel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c4cea_level0_row0" class="row_heading level0 row0" >Baleen (No Prefetch)</th>
#       <td id="T_c4cea_row0_col0" class="data row0 col0" >-16.88%</td>
#       <td id="T_c4cea_row0_col1" class="data row0 col1" >-15.74%</td>
#       <td id="T_c4cea_row0_col2" class="data row0 col2" >-2.28%</td>
#       <td id="T_c4cea_row0_col3" class="data row0 col3" >-14.99%</td>
#       <td id="T_c4cea_row0_col4" class="data row0 col4" >-10.21%</td>
#       <td id="T_c4cea_row0_col5" class="data row0 col5" >-8.41%</td>
#       <td id="T_c4cea_row0_col6" class="data row0 col6" >-5.74%</td>
#       <td id="T_c4cea_row0_col7" class="data row0 col7" >-11.07%</td>
#       <td id="T_c4cea_row0_col8" class="data row0 col8" >-10.61%</td>
#     </tr>
#     <tr>
#       <th id="T_c4cea_level0_row1" class="row_heading level0 row1" >CoinFlip</th>
#       <td id="T_c4cea_row1_col0" class="data row1 col0" >-21.12%</td>
#       <td id="T_c4cea_row1_col1" class="data row1 col1" >-29.27%</td>
#       <td id="T_c4cea_row1_col2" class="data row1 col2" >-4.96%</td>
#       <td id="T_c4cea_row1_col3" class="data row1 col3" >-19.09%</td>
#       <td id="T_c4cea_row1_col4" class="data row1 col4" >-19.50%</td>
#       <td id="T_c4cea_row1_col5" class="data row1 col5" >-16.33%</td>
#       <td id="T_c4cea_row1_col6" class="data row1 col6" >-19.31%</td>
#       <td id="T_c4cea_row1_col7" class="data row1 col7" >-18.81%</td>
#       <td id="T_c4cea_row1_col8" class="data row1 col8" >-18.51%</td>
#     </tr>
#     <tr>
#       <th id="T_c4cea_level0_row2" class="row_heading level0 row2" >RejectX</th>
#       <td id="T_c4cea_row2_col0" class="data row2 col0" >-17.77%</td>
#       <td id="T_c4cea_row2_col1" class="data row2 col1" >-29.18%</td>
#       <td id="T_c4cea_row2_col2" class="data row2 col2" >-21.76%</td>
#       <td id="T_c4cea_row2_col3" class="data row2 col3" >-16.94%</td>
#       <td id="T_c4cea_row2_col4" class="data row2 col4" >-8.52%</td>
#       <td id="T_c4cea_row2_col5" class="data row2 col5" >-4.83%</td>
#       <td id="T_c4cea_row2_col6" class="data row2 col6" >-4.79%</td>
#       <td id="T_c4cea_row2_col7" class="data row2 col7" >-12.01%</td>
#       <td id="T_c4cea_row2_col8" class="data row2 col8" >-14.83%</td>
#     </tr>
#   </tbody>
# </table>
# Raw
#                      P50ServiceTimeUtil@10m
# RegionLabel                         Region1 Region2 Region3 Region4 Region5 Region6 Region7   Avg
# ShortLabel
# Baleen                                11.51    3.36    1.37   20.52   17.52   20.98   20.71 13.71
# Baleen (No Prefetch)                  11.65    3.68    1.37   19.74   17.40   20.24   20.69 13.54
# CoinFlip                              13.19    4.04    1.42   21.71   19.55   23.18   23.37 15.21
# RejectX                               11.91    4.11    1.45   20.24   18.85   21.65   21.92 14.30
# Savings over Baleen
# <style type="text/css">
# #T_4b1bd_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 48.9%, green 48.9%, green 50.0%, transparent 50.0%);
# }
# #T_4b1bd_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 41.4%, green 41.4%, green 50.0%, transparent 50.0%);
# }
# #T_4b1bd_row0_col2, #T_4b1bd_row0_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 49.8%, green 49.8%, green 50.0%, transparent 50.0%);
# }
# #T_4b1bd_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, red 50.0%, red 53.9%, transparent 53.9%);
# }
# #T_4b1bd_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, red 50.0%, red 50.7%, transparent 50.7%);
# }
# #T_4b1bd_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, red 50.0%, red 53.7%, transparent 53.7%);
# }
# #T_4b1bd_row0_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, red 50.0%, red 50.1%, transparent 50.1%);
# }
# #T_4b1bd_row0_col7, #T_4b1bd_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, red 50.0%, red 51.3%, transparent 51.3%);
# }
# #T_4b1bd_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 37.3%, green 37.3%, green 50.0%, transparent 50.0%);
# }
# #T_4b1bd_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 33.3%, green 33.3%, green 50.0%, transparent 50.0%);
# }
# #T_4b1bd_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 45.9%, green 45.9%, green 50.0%, transparent 50.0%);
# }
# #T_4b1bd_row1_col3, #T_4b1bd_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.5%, green 44.5%, green 50.0%, transparent 50.0%);
# }
# #T_4b1bd_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 39.6%, green 39.6%, green 50.0%, transparent 50.0%);
# }
# #T_4b1bd_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.5%, green 40.5%, green 50.0%, transparent 50.0%);
# }
# #T_4b1bd_row1_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 38.6%, green 38.6%, green 50.0%, transparent 50.0%);
# }
# #T_4b1bd_row1_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.1%, green 40.1%, green 50.0%, transparent 50.0%);
# }
# #T_4b1bd_row1_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.0%, green 40.0%, green 50.0%, transparent 50.0%);
# }
# #T_4b1bd_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 46.7%, green 46.7%, green 50.0%, transparent 50.0%);
# }
# #T_4b1bd_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 31.9%, green 31.9%, green 50.0%, transparent 50.0%);
# }
# #T_4b1bd_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.9%, green 43.9%, green 50.0%, transparent 50.0%);
# }
# #T_4b1bd_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.0%, green 43.0%, green 50.0%, transparent 50.0%);
# }
# #T_4b1bd_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 46.9%, green 46.9%, green 50.0%, transparent 50.0%);
# }
# #T_4b1bd_row2_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 45.8%, green 45.8%, green 50.0%, transparent 50.0%);
# }
# #T_4b1bd_row2_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.0%, green 44.0%, green 50.0%, transparent 50.0%);
# }
# </style>
# <table id="T_4b1bd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b1bd_level0_col0" class="col_heading level0 col0" colspan="9">P50ServiceTimeUtil@10m</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >RegionLabel</th>
#       <th id="T_4b1bd_level1_col0" class="col_heading level1 col0" >Region1</th>
#       <th id="T_4b1bd_level1_col1" class="col_heading level1 col1" >Region2</th>
#       <th id="T_4b1bd_level1_col2" class="col_heading level1 col2" >Region3</th>
#       <th id="T_4b1bd_level1_col3" class="col_heading level1 col3" >Region4</th>
#       <th id="T_4b1bd_level1_col4" class="col_heading level1 col4" >Region5</th>
#       <th id="T_4b1bd_level1_col5" class="col_heading level1 col5" >Region6</th>
#       <th id="T_4b1bd_level1_col6" class="col_heading level1 col6" >Region7</th>
#       <th id="T_4b1bd_level1_col7" class="col_heading level1 col7" >Avg</th>
#       <th id="T_4b1bd_level1_col8" class="col_heading level1 col8" >Avg%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ShortLabel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b1bd_level0_row0" class="row_heading level0 row0" >Baleen (No Prefetch)</th>
#       <td id="T_4b1bd_row0_col0" class="data row0 col0" >-1.15%</td>
#       <td id="T_4b1bd_row0_col1" class="data row0 col1" >-8.64%</td>
#       <td id="T_4b1bd_row0_col2" class="data row0 col2" >-0.22%</td>
#       <td id="T_4b1bd_row0_col3" class="data row0 col3" >3.93%</td>
#       <td id="T_4b1bd_row0_col4" class="data row0 col4" >0.72%</td>
#       <td id="T_4b1bd_row0_col5" class="data row0 col5" >3.69%</td>
#       <td id="T_4b1bd_row0_col6" class="data row0 col6" >0.08%</td>
#       <td id="T_4b1bd_row0_col7" class="data row0 col7" >1.28%</td>
#       <td id="T_4b1bd_row0_col8" class="data row0 col8" >-0.23%</td>
#     </tr>
#     <tr>
#       <th id="T_4b1bd_level0_row1" class="row_heading level0 row1" >CoinFlip</th>
#       <td id="T_4b1bd_row1_col0" class="data row1 col0" >-12.71%</td>
#       <td id="T_4b1bd_row1_col1" class="data row1 col1" >-16.67%</td>
#       <td id="T_4b1bd_row1_col2" class="data row1 col2" >-4.10%</td>
#       <td id="T_4b1bd_row1_col3" class="data row1 col3" >-5.50%</td>
#       <td id="T_4b1bd_row1_col4" class="data row1 col4" >-10.38%</td>
#       <td id="T_4b1bd_row1_col5" class="data row1 col5" >-9.48%</td>
#       <td id="T_4b1bd_row1_col6" class="data row1 col6" >-11.40%</td>
#       <td id="T_4b1bd_row1_col7" class="data row1 col7" >-9.85%</td>
#       <td id="T_4b1bd_row1_col8" class="data row1 col8" >-10.03%</td>
#     </tr>
#     <tr>
#       <th id="T_4b1bd_level0_row2" class="row_heading level0 row2" >RejectX</th>
#       <td id="T_4b1bd_row2_col0" class="data row2 col0" >-3.31%</td>
#       <td id="T_4b1bd_row2_col1" class="data row2 col1" >-18.06%</td>
#       <td id="T_4b1bd_row2_col2" class="data row2 col2" >-6.12%</td>
#       <td id="T_4b1bd_row2_col3" class="data row2 col3" >1.34%</td>
#       <td id="T_4b1bd_row2_col4" class="data row2 col4" >-7.04%</td>
#       <td id="T_4b1bd_row2_col5" class="data row2 col5" >-3.05%</td>
#       <td id="T_4b1bd_row2_col6" class="data row2 col6" >-5.54%</td>
#       <td id="T_4b1bd_row2_col7" class="data row2 col7" >-4.15%</td>
#       <td id="T_4b1bd_row2_col8" class="data row2 col8" >-5.97%</td>
#     </tr>
#   </tbody>
# </table>
# \newcommand{\PeakSavingsOverNoCachingPercent}{28.1\%}
# \newcommand{\PeakSavingsOverRejectxPercent}{12.0\%}
# \newcommand{\PeakSavingsOverCoinflipPercent}{18.8\%}
# \newcommand{\PeakSavingsOverRejectxPercentMin}{4.8\%}
# \newcommand{\PeakSavingsOverRejectxPercentMax}{29.2\%}
# \newcommand{\MedianSavingsOverRejectxPercent}{4.2\%}
# \newcommand{\MedianSavingsOverCoinflipPercent}{4.2\%}

# %%
# d1a, d1r = stats(df_01f, y=y, agg='RegionLabel', verbose=2)
y2 = 'IOPSMissRatio'
d1a_50, d1r_50 = stats(df_01f, y=y2, agg='RegionLabel', verbose=2)
latex_macros({
    # 'PeakSavingsOverNoCachingPercent': d1a[y].loc["Baleen", "Avg"],
    # 'PeakSavingsOverRejectxPercent': d1r[y].loc["RejectX", "Avg"],
    # 'PeakSavingsOverCoinflipPercent': d1r[y].loc["CoinFlip", "Avg"],
    # 'PeakSavingsOverRejectxPercentMin': d1r[y].loc["RejectX"].min(),
    # 'PeakSavingsOverRejectxPercentMax': d1r[y].loc["RejectX"].max(),
    'IOSavingsOverRejectxPercent': d1r_50[y2].loc["RejectX", "Avg"],
    'IOSavingsOverCoinflipPercent': d1r_50[y2].loc["CoinFlip", "Avg"],
})
# Out:
# Raw
#                      IOPSMissRatio
# RegionLabel                Region1 Region2 Region3 Region4 Region5 Region6 Region7  Avg
# ShortLabel
# Baleen                        0.47    0.29    0.26    0.54    0.57    0.63    0.71 0.49
# Baleen (No Prefetch)          0.54    0.43    0.28    0.54    0.57    0.62    0.71 0.53
# CoinFlip                      0.66    0.49    0.30    0.62    0.67    0.74    0.84 0.62
# RejectX                       0.57    0.49    0.32    0.56    0.63    0.67    0.76 0.57
# Savings over Baleen
# <style type="text/css">
# #T_58f81_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 35.9%, green 35.9%, green 50.0%, transparent 50.0%);
# }
# #T_58f81_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 17.3%, green 17.3%, green 50.0%, transparent 50.0%);
# }
# #T_58f81_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 41.8%, green 41.8%, green 50.0%, transparent 50.0%);
# }
# #T_58f81_row0_col3, #T_58f81_row0_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 49.8%, green 49.8%, green 50.0%, transparent 50.0%);
# }
# #T_58f81_row0_col4, #T_58f81_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, red 50.0%, red 50.2%, transparent 50.2%);
# }
# #T_58f81_row0_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.5%, green 43.5%, green 50.0%, transparent 50.0%);
# }
# #T_58f81_row0_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 42.2%, green 42.2%, green 50.0%, transparent 50.0%);
# }
# #T_58f81_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.2%, green 20.2%, green 50.0%, transparent 50.0%);
# }
# #T_58f81_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 8.8%, green 8.8%, green 50.0%, transparent 50.0%);
# }
# #T_58f81_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 35.6%, green 35.6%, green 50.0%, transparent 50.0%);
# }
# #T_58f81_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 37.4%, green 37.4%, green 50.0%, transparent 50.0%);
# }
# #T_58f81_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 34.7%, green 34.7%, green 50.0%, transparent 50.0%);
# }
# #T_58f81_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 35.1%, green 35.1%, green 50.0%, transparent 50.0%);
# }
# #T_58f81_row1_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 34.4%, green 34.4%, green 50.0%, transparent 50.0%);
# }
# #T_58f81_row1_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 30.0%, green 30.0%, green 50.0%, transparent 50.0%);
# }
# #T_58f81_row1_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.5%, green 29.5%, green 50.0%, transparent 50.0%);
# }
# #T_58f81_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 31.9%, green 31.9%, green 50.0%, transparent 50.0%);
# }
# #T_58f81_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 8.9%, green 8.9%, green 50.0%, transparent 50.0%);
# }
# #T_58f81_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.9%, green 29.9%, green 50.0%, transparent 50.0%);
# }
# #T_58f81_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 47.1%, green 47.1%, green 50.0%, transparent 50.0%);
# }
# #T_58f81_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 39.9%, green 39.9%, green 50.0%, transparent 50.0%);
# }
# #T_58f81_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.1%, green 43.1%, green 50.0%, transparent 50.0%);
# }
# #T_58f81_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 42.9%, green 42.9%, green 50.0%, transparent 50.0%);
# }
# #T_58f81_row2_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 36.3%, green 36.3%, green 50.0%, transparent 50.0%);
# }
# #T_58f81_row2_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 34.8%, green 34.8%, green 50.0%, transparent 50.0%);
# }
# </style>
# <table id="T_58f81">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_58f81_level0_col0" class="col_heading level0 col0" colspan="9">IOPSMissRatio</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >RegionLabel</th>
#       <th id="T_58f81_level1_col0" class="col_heading level1 col0" >Region1</th>
#       <th id="T_58f81_level1_col1" class="col_heading level1 col1" >Region2</th>
#       <th id="T_58f81_level1_col2" class="col_heading level1 col2" >Region3</th>
#       <th id="T_58f81_level1_col3" class="col_heading level1 col3" >Region4</th>
#       <th id="T_58f81_level1_col4" class="col_heading level1 col4" >Region5</th>
#       <th id="T_58f81_level1_col5" class="col_heading level1 col5" >Region6</th>
#       <th id="T_58f81_level1_col6" class="col_heading level1 col6" >Region7</th>
#       <th id="T_58f81_level1_col7" class="col_heading level1 col7" >Avg</th>
#       <th id="T_58f81_level1_col8" class="col_heading level1 col8" >Avg%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ShortLabel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_58f81_level0_row0" class="row_heading level0 row0" >Baleen (No Prefetch)</th>
#       <td id="T_58f81_row0_col0" class="data row0 col0" >-14.11%</td>
#       <td id="T_58f81_row0_col1" class="data row0 col1" >-32.67%</td>
#       <td id="T_58f81_row0_col2" class="data row0 col2" >-8.20%</td>
#       <td id="T_58f81_row0_col3" class="data row0 col3" >-0.20%</td>
#       <td id="T_58f81_row0_col4" class="data row0 col4" >0.20%</td>
#       <td id="T_58f81_row0_col5" class="data row0 col5" >0.22%</td>
#       <td id="T_58f81_row0_col6" class="data row0 col6" >-0.15%</td>
#       <td id="T_58f81_row0_col7" class="data row0 col7" >-6.49%</td>
#       <td id="T_58f81_row0_col8" class="data row0 col8" >-7.84%</td>
#     </tr>
#     <tr>
#       <th id="T_58f81_level0_row1" class="row_heading level0 row1" >CoinFlip</th>
#       <td id="T_58f81_row1_col0" class="data row1 col0" >-29.77%</td>
#       <td id="T_58f81_row1_col1" class="data row1 col1" >-41.21%</td>
#       <td id="T_58f81_row1_col2" class="data row1 col2" >-14.37%</td>
#       <td id="T_58f81_row1_col3" class="data row1 col3" >-12.62%</td>
#       <td id="T_58f81_row1_col4" class="data row1 col4" >-15.33%</td>
#       <td id="T_58f81_row1_col5" class="data row1 col5" >-14.87%</td>
#       <td id="T_58f81_row1_col6" class="data row1 col6" >-15.56%</td>
#       <td id="T_58f81_row1_col7" class="data row1 col7" >-20.01%</td>
#       <td id="T_58f81_row1_col8" class="data row1 col8" >-20.53%</td>
#     </tr>
#     <tr>
#       <th id="T_58f81_level0_row2" class="row_heading level0 row2" >RejectX</th>
#       <td id="T_58f81_row2_col0" class="data row2 col0" >-18.09%</td>
#       <td id="T_58f81_row2_col1" class="data row2 col1" >-41.10%</td>
#       <td id="T_58f81_row2_col2" class="data row2 col2" >-20.15%</td>
#       <td id="T_58f81_row2_col3" class="data row2 col3" >-2.87%</td>
#       <td id="T_58f81_row2_col4" class="data row2 col4" >-10.10%</td>
#       <td id="T_58f81_row2_col5" class="data row2 col5" >-6.89%</td>
#       <td id="T_58f81_row2_col6" class="data row2 col6" >-7.13%</td>
#       <td id="T_58f81_row2_col7" class="data row2 col7" >-13.75%</td>
#       <td id="T_58f81_row2_col8" class="data row2 col8" >-15.19%</td>
#     </tr>
#   </tbody>
# </table>
# \newcommand{\IOSavingsOverRejectxPercent}{13.7\%}
# \newcommand{\IOSavingsOverCoinflipPercent}{20.0\%}

# %%
# d1a, d1r = stats(df_01f, y=y, agg='RegionLabel', verbose=2)
y2 = 'BandwidthMissRatio'
d1a_50, d1r_50 = stats(df_01f, y=y2, agg='RegionLabel', verbose=2)
latex_macros({
    # 'PeakSavingsOverNoCachingPercent': d1a[y].loc["Baleen", "Avg"],
    # 'PeakSavingsOverRejectxPercent': d1r[y].loc["RejectX", "Avg"],
    # 'PeakSavingsOverCoinflipPercent': d1r[y].loc["CoinFlip", "Avg"],
    # 'PeakSavingsOverRejectxPercentMin': d1r[y].loc["RejectX"].min(),
    # 'PeakSavingsOverRejectxPercentMax': d1r[y].loc["RejectX"].max(),
    'BWSavingsOverRejectxPercent': d1r_50[y2].loc["RejectX", "Avg"],
    'BWSavingsOverCoinflipPercent': d1r_50[y2].loc["CoinFlip", "Avg"],
})
# Out:
# Raw
#                      BandwidthMissRatio
# RegionLabel                     Region1 Region2 Region3 Region4 Region5 Region6 Region7  Avg
# ShortLabel
# Baleen                             0.75    0.57    0.42    0.63    0.69    0.72    0.77 0.65
# Baleen (No Prefetch)               0.72    0.53    0.41    0.60    0.68    0.68    0.77 0.63
# CoinFlip                           0.80    0.56    0.43    0.65    0.75    0.77    0.85 0.69
# RejectX                            0.73    0.56    0.43    0.61    0.73    0.73    0.81 0.66
# Savings over Baleen
# <style type="text/css">
# #T_04a55_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, red 50.0%, red 53.4%, transparent 53.4%);
# }
# #T_04a55_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, red 50.0%, red 59.2%, transparent 59.2%);
# }
# #T_04a55_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, red 50.0%, red 53.3%, transparent 53.3%);
# }
# #T_04a55_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, red 50.0%, red 55.4%, transparent 55.4%);
# }
# #T_04a55_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, red 50.0%, red 52.2%, transparent 52.2%);
# }
# #T_04a55_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, red 50.0%, red 55.1%, transparent 55.1%);
# }
# #T_04a55_row0_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, red 50.0%, red 50.4%, transparent 50.4%);
# }
# #T_04a55_row0_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, red 50.0%, red 53.9%, transparent 53.9%);
# }
# #T_04a55_row0_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, red 50.0%, red 54.1%, transparent 54.1%);
# }
# #T_04a55_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.2%, green 43.2%, green 50.0%, transparent 50.0%);
# }
# #T_04a55_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, red 50.0%, red 51.7%, transparent 51.7%);
# }
# #T_04a55_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 48.5%, green 48.5%, green 50.0%, transparent 50.0%);
# }
# #T_04a55_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 47.2%, green 47.2%, green 50.0%, transparent 50.0%);
# }
# #T_04a55_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 42.9%, green 42.9%, green 50.0%, transparent 50.0%);
# }
# #T_04a55_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 42.8%, green 42.8%, green 50.0%, transparent 50.0%);
# }
# #T_04a55_row1_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.6%, green 40.6%, green 50.0%, transparent 50.0%);
# }
# #T_04a55_row1_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.6%, green 44.6%, green 50.0%, transparent 50.0%);
# }
# #T_04a55_row1_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 45.3%, green 45.3%, green 50.0%, transparent 50.0%);
# }
# #T_04a55_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, red 50.0%, red 52.1%, transparent 52.1%);
# }
# #T_04a55_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, red 50.0%, red 52.6%, transparent 52.6%);
# }
# #T_04a55_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 48.1%, green 48.1%, green 50.0%, transparent 50.0%);
# }
# #T_04a55_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, red 50.0%, red 53.1%, transparent 53.1%);
# }
# #T_04a55_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 45.1%, green 45.1%, green 50.0%, transparent 50.0%);
# }
# #T_04a55_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 47.9%, green 47.9%, green 50.0%, transparent 50.0%);
# }
# #T_04a55_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 45.4%, green 45.4%, green 50.0%, transparent 50.0%);
# }
# #T_04a55_row2_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 49.0%, green 49.0%, green 50.0%, transparent 50.0%);
# }
# #T_04a55_row2_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 49.2%, green 49.2%, green 50.0%, transparent 50.0%);
# }
# </style>
# <table id="T_04a55">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_04a55_level0_col0" class="col_heading level0 col0" colspan="9">BandwidthMissRatio</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >RegionLabel</th>
#       <th id="T_04a55_level1_col0" class="col_heading level1 col0" >Region1</th>
#       <th id="T_04a55_level1_col1" class="col_heading level1 col1" >Region2</th>
#       <th id="T_04a55_level1_col2" class="col_heading level1 col2" >Region3</th>
#       <th id="T_04a55_level1_col3" class="col_heading level1 col3" >Region4</th>
#       <th id="T_04a55_level1_col4" class="col_heading level1 col4" >Region5</th>
#       <th id="T_04a55_level1_col5" class="col_heading level1 col5" >Region6</th>
#       <th id="T_04a55_level1_col6" class="col_heading level1 col6" >Region7</th>
#       <th id="T_04a55_level1_col7" class="col_heading level1 col7" >Avg</th>
#       <th id="T_04a55_level1_col8" class="col_heading level1 col8" >Avg%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ShortLabel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04a55_level0_row0" class="row_heading level0 row0" >Baleen (No Prefetch)</th>
#       <td id="T_04a55_row0_col0" class="data row0 col0" >3.38%</td>
#       <td id="T_04a55_row0_col1" class="data row0 col1" >9.21%</td>
#       <td id="T_04a55_row0_col2" class="data row0 col2" >3.28%</td>
#       <td id="T_04a55_row0_col3" class="data row0 col3" >5.40%</td>
#       <td id="T_04a55_row0_col4" class="data row0 col4" >2.15%</td>
#       <td id="T_04a55_row0_col5" class="data row0 col5" >5.07%</td>
#       <td id="T_04a55_row0_col6" class="data row0 col6" >0.39%</td>
#       <td id="T_04a55_row0_col7" class="data row0 col7" >3.89%</td>
#       <td id="T_04a55_row0_col8" class="data row0 col8" >4.13%</td>
#     </tr>
#     <tr>
#       <th id="T_04a55_level0_row1" class="row_heading level0 row1" >CoinFlip</th>
#       <td id="T_04a55_row1_col0" class="data row1 col0" >-6.81%</td>
#       <td id="T_04a55_row1_col1" class="data row1 col1" >1.72%</td>
#       <td id="T_04a55_row1_col2" class="data row1 col2" >-1.55%</td>
#       <td id="T_04a55_row1_col3" class="data row1 col3" >-2.84%</td>
#       <td id="T_04a55_row1_col4" class="data row1 col4" >-7.06%</td>
#       <td id="T_04a55_row1_col5" class="data row1 col5" >-7.20%</td>
#       <td id="T_04a55_row1_col6" class="data row1 col6" >-9.44%</td>
#       <td id="T_04a55_row1_col7" class="data row1 col7" >-5.37%</td>
#       <td id="T_04a55_row1_col8" class="data row1 col8" >-4.74%</td>
#     </tr>
#     <tr>
#       <th id="T_04a55_level0_row2" class="row_heading level0 row2" >RejectX</th>
#       <td id="T_04a55_row2_col0" class="data row2 col0" >2.07%</td>
#       <td id="T_04a55_row2_col1" class="data row2 col1" >2.57%</td>
#       <td id="T_04a55_row2_col2" class="data row2 col2" >-1.95%</td>
#       <td id="T_04a55_row2_col3" class="data row2 col3" >3.13%</td>
#       <td id="T_04a55_row2_col4" class="data row2 col4" >-4.87%</td>
#       <td id="T_04a55_row2_col5" class="data row2 col5" >-2.06%</td>
#       <td id="T_04a55_row2_col6" class="data row2 col6" >-4.62%</td>
#       <td id="T_04a55_row2_col7" class="data row2 col7" >-1.04%</td>
#       <td id="T_04a55_row2_col8" class="data row2 col8" >-0.82%</td>
#     </tr>
#   </tbody>
# </table>
# \newcommand{\BWSavingsOverRejectxPercent}{1.0\%}
# \newcommand{\BWSavingsOverCoinflipPercent}{5.4\%}

# %%
figlabels
# Out:
# {'peak-st-util': 'P100ServiceTimeUtil@10m',
#  'median-st-util': 'P50ServiceTimeUtil@10m',
#  'mean-st-util': 'MeanServiceTimeUtil',
#  'peak-st-ratio': 'P100ServiceTimePercent@10m',
#  'median-st-ratio': 'P50ServiceTimePercent@10m',
#  'mean-st-ratio': 'MeanServiceTimeUsedPercent',
#  'iops-miss-ratio': 'IO miss rate (%)',
#  'bw-miss-ratio': 'Byte miss rate (%)'}

# %%
for savel, y in figlabels.items():
    # if "Mean" in y:
    #     continue
    plt.figure()
    plot_bar(df_01f, y=y)
    # savefig("traces", f"{savel}_wr-34")
