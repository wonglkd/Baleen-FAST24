# %% [markdown]
# This is meant to match the 'Getting Started' section of the README, which is available at
# https://github.com/wonglkd/Baleen-FAST24

# %% [markdown]
# This notebook will guide you through the process of doing some quick experiments on the shared Jupyter server, which has limited RAM and disk. For more, you will likely want to start a dedicated server (see the other notebook).

# %% [markdown]
# # Getting started

# %% [markdown]
# ### 1. Clone repository

# %%
if [ ! -d Baleen-FAST24 ]; then
    git clone --recurse-submodules https://github.com/wonglkd/Baleen-FAST24.git
fi

# %%
cd Baleen-FAST24

# %%
git pull --recurse-submodules
# Out:
# Fetching submodule BCacheSim
# Already up to date.

# %% [markdown]
# ### 2. Install dependencies

# %%
python3 -m pip install --user -r BCacheSim/install/requirements.txt
# Out:
# WARNING: Ignoring invalid distribution -umpy (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/opt/conda/lib/python3.10/site-packages)
# Collecting lightgbm==3.3.5
#   Using cached lightgbm-3.3.5-py3-none-manylinux1_x86_64.whl (2.0 MB)
# Collecting numpy==1.24.2
#   Using cached numpy-1.24.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# Requirement already satisfied: pandas==1.5.3 in /opt/conda/lib/python3.10/site-packages (from -r BCacheSim/install/requirements.txt (line 3)) (1.5.3)
# Collecting scikit-learn==1.2.2
#   Using cached scikit_learn-1.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.6 MB)
# Requirement already satisfied: spookyhash in /opt/conda/lib/python3.10/site-packages (from -r BCacheSim/install/requirements.txt (line 5)) (2.1.0)
# Collecting jsonargparse
#   Using cached jsonargparse-4.27.1-py3-none-any.whl (189 kB)
# Requirement already satisfied: compress_json in /opt/conda/lib/python3.10/site-packages (from -r BCacheSim/install/requirements.txt (line 7)) (1.0.10)
# Collecting compress_pickle
#   Using cached compress_pickle-2.1.0-py3-none-any.whl (24 kB)
# Collecting retry
#   Using cached retry-0.9.2-py2.py3-none-any.whl (8.0 kB)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from -r BCacheSim/install/requirements.txt (line 10)) (5.8.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from -r BCacheSim/install/requirements.txt (line 11)) (4.65.0)
# Collecting scipy==1.10.1
#   Using cached scipy-1.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.4 MB)
# Collecting redis
#   Using cached redis-5.0.1-py3-none-any.whl (250 kB)
# Collecting matplotlib==3.7.1
#   Using cached matplotlib-3.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
# Collecting seaborn==0.12.1
#   Using cached seaborn-0.12.1-py3-none-any.whl (288 kB)
# Requirement already satisfied: pqdict in /opt/conda/lib/python3.10/site-packages (from -r BCacheSim/install/requirements.txt (line 16)) (1.3.0)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.10/site-packages (from lightgbm==3.3.5->-r BCacheSim/install/requirements.txt (line 1)) (0.40.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.10/site-packages (from pandas==1.5.3->-r BCacheSim/install/requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas==1.5.3->-r BCacheSim/install/requirements.txt (line 3)) (2021.1)
# Collecting joblib>=1.1.1
#   Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn==1.2.2->-r BCacheSim/install/requirements.txt (line 4)) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib==3.7.1->-r BCacheSim/install/requirements.txt (line 14)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib==3.7.1->-r BCacheSim/install/requirements.txt (line 14)) (0.12.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib==3.7.1->-r BCacheSim/install/requirements.txt (line 14)) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib==3.7.1->-r BCacheSim/install/requirements.txt (line 14)) (1.4.5)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib==3.7.1->-r BCacheSim/install/requirements.txt (line 14)) (4.45.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib==3.7.1->-r BCacheSim/install/requirements.txt (line 14)) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib==3.7.1->-r BCacheSim/install/requirements.txt (line 14)) (10.1.0)
# Requirement already satisfied: PyYAML>=3.13 in /opt/conda/lib/python3.10/site-packages (from jsonargparse->-r BCacheSim/install/requirements.txt (line 6)) (5.3.1)
# Requirement already satisfied: py<2.0.0,>=1.4.26 in /opt/conda/lib/python3.10/site-packages (from retry->-r BCacheSim/install/requirements.txt (line 9)) (1.11.0)
# Requirement already satisfied: decorator>=3.4.2 in /opt/conda/lib/python3.10/site-packages (from retry->-r BCacheSim/install/requirements.txt (line 9)) (5.1.1)
# Collecting async-timeout>=4.0.2
#   Using cached async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas==1.5.3->-r BCacheSim/install/requirements.txt (line 3)) (1.16.0)
# WARNING: Ignoring invalid distribution -umpy (/opt/conda/lib/python3.10/site-packages)
# Installing collected packages: retry, numpy, jsonargparse, joblib, compress_pickle, async-timeout, scipy, redis, scikit-learn, matplotlib, seaborn, lightgbm
#   WARNING: The scripts f2py, f2py3 and f2py3.10 are installed in '/home/wonglkd_globusid_org/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed async-timeout-4.0.3 compress_pickle-2.1.0 joblib-1.3.2 jsonargparse-4.27.1 lightgbm-3.3.5 matplotlib-3.7.1 numpy-1.24.2 redis-5.0.1 retry-0.9.2 scikit-learn-1.2.2 scipy-1.10.1 seaborn-0.12.1
# WARNING: Ignoring invalid distribution -umpy (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/opt/conda/lib/python3.10/site-packages)

# %% [markdown]
# ### 3. Download trace files

# %%
cd data
bash get-tectonic.sh
cd ..
# Out:
# bash: cd: data: No such file or directory

# %% [markdown]
# ## Do a simple experiment

# %% [markdown]
# ### Run RejectX baseline (6 mins)

# %%
./BCacheSim/run_py.sh py -B -m BCacheSim.cachesim.simulate_ap --config runs/example/rejectx/config.json
# Out:
# bash: fg: %%time: no such job
# + PYTHON=py
# + ARGS='-B -m BCacheSim.cachesim.simulate_ap --config runs/example/rejectx/config.json'
# + case "$PYTHON" in
# + PYTHON_BIN=python
# +++ dirname ./BCacheSim/run_py.sh
# ++ cd ./BCacheSim
# ++ pwd
# + DIR=/work/Baleen-FAST24-Artifact/Baleen-FAST24/BCacheSim
# + cd /work/Baleen-FAST24-Artifact/Baleen-FAST24/BCacheSim/..
# + stdbuf -eL -oL python -B -m BCacheSim.cachesim.simulate_ap --config runs/example/rejectx/config.json
# {'admit_only_prefetches': False,
#  'ap': 'rejectx',
#  'ap_chunk_threshold': None,
#  'ap_feat_subset': None,
#  'ap_probability': 0.508154,
#  'ap_threshold': 1.0,
#  'batch_size': 512,
#  'block_level': False,
#  'cache_elems': None,
#  'cachelib_trace': None,
#  'coinflip_ap': False,
#  'config': ['runs/example/rejectx/config.json'],
#  'debug': False,
#  'early_evict': None,
#  'ep_analysis': None,
#  'evict_by_episode': False,
#  'eviction_policy': 'LRU',
#  'fast': False,
#  'fifo': False,
#  'flashieldprob_ap_min_hits': None,
#  'flip_threshold': True,
#  'hybrid_ap_threshold': None,
#  'ignore_existing': False,
#  'job_id': None,
#  'learned_ap': False,
#  'learned_ap_filter_count': 6,
#  'learned_ap_granularity': None,
#  'learned_ap_model_path': None,
#  'learned_size': False,
#  'limit': None,
#  'lirs': False,
#  'log_decisions': False,
#  'log_episodes': False,
#  'log_evictions': False,
#  'log_interval': 600.0,
#  'log_prefetch': False,
#  'log_req': False,
#  'offline_ap': False,
#  'offline_ap_decisions': None,
#  'one_chunk': False,
#  'opt_ap_threshold': None,
#  'optplus_args': None,
#  'output_dir': 'runs/example/rejectx',
#  'override': False,
#  'peak_strategy': None,
#  'prefetch': None,
#  'prefetch_range': 'episode',
#  'prefetch_when': 'never',
#  'prefetch_when_threshold': None,
#  'prefetcher_model_path': None,
#  'profile': False,
#  'ram_ap_clone': False,
#  'ram_cache': False,
#  'ram_cache_elems': None,
#  'ram_cache_size_gb': 10.0,
#  'rejectx_ap': True,
#  'rejectx_ap_factor': None,
#  'rejectx_ap_threshold': None,
#  'retrain_interval_hrs': None,
#  'size_gb': 366.475,
#  'size_opt': 'access',
#  'stats_start': 86400.0,
#  'trace': 'data/tectonic/201910/Region1/full_0_0.1.trace',
#  'tracefile': 'data/tectonic/201910/Region1/full_0_0.1.trace',
#  'train_history_hrs': None,
#  'ttl_model_path': None,
#  'write_mbps': 0}
# Command: /work/Baleen-FAST24-Artifact/Baleen-FAST24/BCacheSim/cachesim/../run_py.sh py /work/Baleen-FAST24-Artifact/Baleen-FAST24/BCacheSim/cachesim/simulate_ap.py --config runs/example/rejectx/config.json
# Output dir: runs/example/rejectx/rejectx-ap-1_0.508154_lru_366.475GB
# Logging to runs/example/rejectx/rejectx-ap-1_0.508154_lru_366.475GB/full_0_0.1.out
# Reading from file data/tectonic/201910/Region1/full_0_0.1.trace
# {'total_iops': 147794, 'total_iops_get': 127305, 'total_iops_put': 20489, 'max_key': ('9997015', Acc(block=9997015, offset=0, size=8388608, ts=1572298799.127971, features=op=OpType.GET_PERM, pipeline=1, namespace=9, user=23)), 'trace_duration_secs': 604641.98, 'start_ts': 1572074461.57806, 'end_ts': 1572679103.557401, 'filename': 'data/tectonic/201910/Region1/full_0_0.1.trace', 'trace_hash': b'859229345a0fa792582df0db8cd56c4d', 'kwargs_hash': '5a0a05', 'kwargs': {'only_gets': False}}
# [0] TimeLeft | [1] I   | [2] TraceTime | [3] Hrs$ | [4] %GETs | [5] GETs$ | [6] PUTs$ | [7] STGet%$ | [8] PeakST%$ | [9] STGetNoCa%$ | [10] STPut%$ | [11] ReqMBs$ | [12] GetMBs$ | [13] PutMBs$ | [14] FlaMBs$ | [15] PreMBs$ | [16] STSaved%$ | [17] Accept%$ | [18] STLate%$ | [19] Wasted%$ | [20] EA$ | [21] AvgIAMax | [22] RAMGb | [23] EstTotalTime | [24] Speedup$ | [25] GET/Ts$ | [26] GET/s$ | [27] WarningRootEpNotfound | [28] WarningPutStartsAfterZero | [29] Flashcache/warningAdmittedEpsUnknown
# [0] 4.4m     | [1] 1   | [2] 0.17h     | [3] 0.2  | [4] 0.2   | [5] 228   | [6] 17    | [7] 20.75   | [8] 0.00     | [9] 29.16       | [10] 5.11    | [11] 881.34  | [12] 684.77  | [13] 216.82  | [14] 98.39   | [15] 0.00    | [16] 28.9%     | [17] 14.38%   | [18] 6.6%     | [19] 0.0%     | [20] 0   | [21] (10,28s) | [22] 0.2   | [23] 4.4m         | [24] 1.26     | [25] 0.4     | [26] 476.3  | [27] 228 | [28] 17 | [29] 476
# [0] TimeLeft | [1] I   | [2] TraceTime | [3] Hrs$ | [4] %GETs | [5] GETs$ | [6] PUTs$ | [7] STGet%$ | [8] PeakST%$ | [9] STGetNoCa%$ | [10] STPut%$ | [11] ReqMBs$ | [12] GetMBs$ | [13] PutMBs$ | [14] FlaMBs$ | [15] PreMBs$ | [16] STSaved%$ | [17] Accept%$ | [18] STLate%$ | [19] Wasted%$ | [20] EA$       | [21] AvgIAMax  | [22] RAMGb | [23] EstTotalTime | [24] Speedup$ | [25] GET/Ts$ | [26] GET/s$ | [27] WarningRootEpNotfound | [28] WarningPutStartsAfterZero | [29] Flashcache/warningAdmittedEpsUnknown | [30] Flashcache/warningAdmitsPartial | [31] Flashcache/warningAdmitsPartialEpisodes | [32] Flashcache/warningEvictedEpisodenotfound
# [0] 4.7m     | [1] 145 | [2] 1d0.17h   | [3] 24.0 | [4] 14.3  | [5] 18030 | [6] 2960  | [7] 12.55   | [8] 23.10    | [9] 20.66       | [10] 5.09    | [11] 720.15  | [12] 445.05  | [13] 205.75  | [14] 30.57   | [15] 0.00    | [16] 39.2%     | [17] 6.81%    | [18] 2.9%     | [19] 42.0%    | [20] (1831,2h) | [21] (352,24m) | [22] 0.3   | [23] 5.5m         | [24] 1.85     | [25] 0.2     | [26] 386.7  | [27] 18258 | [28] 2977 | [29] 21607 | [30] 1495 | [31] 571 | [32] 18606
# [0] 3.8m     | [1] 290 | [2] 2d0.33h   | [3] 24.2 | [4] 27.5  | [5] 16688 | [6] 3414  | [7] 12.18   | [8] 24.27    | [9] 16.26       | [10] 5.79    | [11] 521.68  | [12] 403.13  | [13] 233.57  | [14] 29.09   | [15] 0.00    | [16] 25.1%     | [17] 3.56%    | [18] 3.5%     | [19] 46.8%    | [20] (1830,2h) | [21] (338,22m) | [22] 0.3   | [23] 5.2m         | [24] 2.13     | [25] 0.2     | [26] 408.4  | [27] 34946 | [28] 6391 | [29] 41854 | [30] 3992 | [31] 1238 | [32] 38853
# [0] 3.7m     | [1] 434 | [2] 3d0.34h   | [3] 24.0 | [4] 40.4  | [5] 16541 | [6] 3206  | [7] 12.22   | [8] 24.27    | [9] 16.37       | [10] 5.21    | [11] 528.04  | [12] 419.45  | [13] 207.33  | [14] 33.07   | [15] 0.00    | [16] 25.4%     | [17] 2.73%    | [18] 3.9%     | [19] 46.0%    | [20] (1702,2h) | [21] (329,22m) | [22] 0.3   | [23] 5.9m         | [24] 1.80     | [25] 0.2     | [26] 344.5  | [27] 51487 | [28] 9597 | [29] 64722 | [30] 5662 | [31] 1906 | [32] 61721
# [0] 2.6m     | [1] 579 | [2] 4d0.5h    | [3] 24.2 | [4] 55.3  | [5] 18905 | [6] 3238  | [7] 14.95   | [8] 29.18    | [9] 20.01       | [10] 4.97    | [11] 672.47  | [12] 526.45  | [13] 194.52  | [14] 45.88   | [15] 0.00    | [16] 25.3%     | [17] 2.70%    | [18] 4.5%     | [19] 37.4%    | [20] (1317,1h) | [21] (318,21m) | [22] 0.3   | [23] 5.7m         | [24] 1.68     | [25] 0.2     | [26] 364.3  | [27] 70392 | [28] 12835 | [29] 96642 | [30] 7839 | [31] 2767 | [32] 93641
# [0] 1.8m     | [1] 723 | [2] 5d0.5h    | [3] 24.0 | [4] 69.5  | [5] 18037 | [6] 2961  | [7] 15.14   | [8] 33.41    | [9] 19.43       | [10] 4.80    | [11] 657.17  | [12] 537.16  | [13] 190.83  | [14] 37.78   | [15] 0.00    | [16] 22.1%     | [17] 1.72%    | [18] 3.8%     | [19] 37.7%    | [20] (1465,2h) | [21] (326,21m) | [22] 0.3   | [23] 5.7m         | [24] 1.75     | [25] 0.2     | [26] 365.1  | [27] 88429 | [28] 15796 | [29] 122753 | [30] 9853 | [31] 3618 | [32] 119752
# [0] 0.78m    | [1] 868 | [2] 6d0.67h   | [3] 24.2 | [4] 85.7  | [5] 20679 | [6] 2395  | [7] 16.10   | [8] 33.41    | [9] 21.25       | [10] 4.02    | [11] 702.84  | [12] 572.59  | [13] 161.70  | [14] 38.76   | [15] 0.00    | [16] 24.2%     | [17] 1.43%    | [18] 3.5%     | [19] 40.3%    | [20] (1442,2h) | [21] (339,22m) | [22] 0.3   | [23] 5.6m         | [24] 1.63     | [25] 0.2     | [26] 387.9  | [27] 109108 | [28] 18191 | [29] 149733 | [30] 11526 | [31] 4352 | [32] 146732
# [0] TimeLeft | [1] I    | [2] TraceTime | [3] Hrs$ | [4] %GETs | [5] GETs$ | [6] PUTs$ | [7] STGet%$ | [8] PeakST%$ | [9] STGetNoCa%$ | [10] STPut%$ | [11] ReqMBs$ | [12] GetMBs$ | [13] PutMBs$ | [14] FlaMBs$ | [15] PreMBs$ | [16] STSaved%$ | [17] Accept%$ | [18] STLate%$ | [19] Wasted%$ | [20] EA$       | [21] AvgIAMax  | [22] RAMGb | [23] EstTotalTime | [24] Speedup$ | [25] GET/Ts$ | [26] GET/s$ | [27] WarningRootEpNotfound | [28] WarningPutStartsAfterZero | [29] Flashcache/warningAdmittedEpsUnknown | [30] Flashcache/warningAdmitsPartial | [31] Flashcache/warningAdmitsPartialEpisodes | [32] Flashcache/warningEvictedEpisodenotfound
# [0]          | [1] 1008 | [2] 6d24h     | [3] 23.3 | [4] 100.0 | [5] 18197 | [6] 2298  | [7] 14.11   | [8] 33.41    | [9] 20.14       | [10] 4.12    | [11] 679.91  | [12] 519.25  | [13] 167.19  | [14] 33.68   | [15] 0.00    | [16] 29.9%     | [17] 1.02%    | [18] 3.2%     | [19] 36.4%    | [20] (1564,2h) | [21] (348,23m) | [22] 0.4   | [23] 5.6m         | [24] 1.78     | [25] 0.2     | [26] 387.2  | [27] 127305 | [28] 20489 | [29] 172322 | [30] 12776 | [31] 5002 | [32] 169321
# Results preview:
#  Trace: {'region': '201910', 'sample_ratio': 0.1, 'start': 0.0, 'only_gets': False}
#  AP: rejectx, RejectX(threshold=1.0, window=1525.48, factor=0.508154)
#  Eviction Policy: LRU, <BCacheSim.cachesim.eviction_policies.QueueCache object at 0x7efe086773a0>
#  Average TTL: 0.00 s
#  Duration so far: 6 days 23 hrs 57 mins 22 secs
#  Duration: 6 days 23 hrs 57 mins 22 secs (10 mins intervals)
#  Service Time Utilization (%)                         - 18.76250
#  Service Time Utilization (%) [GET]                   - 13.90071
#  Service Time Utilization (%) [PUT]                   - 4.86179
#  Peak Service Time Utilization (%)                    - 44.35496
#  Peak Service Time Utilization (%) [PUT]              - 13.78412
#  Peak Service Time Utilization (%) [GET]              - 32.85580
#  P99 Service Time Utilization (%)                     - 29.60424
#  P99.9 Service Time Utilization (%)                   - 39.80833
#  P99.99 Service Time Utilization (%)                  - 43.90030
#  P99 Service Time Utilization (%) [GET]               - 23.41674
#  P99.9 Service Time Utilization (%) [GET]             - 30.71864
#  P99.99 Service Time Utilization (%) [GET]            - 32.64209
#  P99 Service Time Utilization (%) [GET-NoCache]       - 36.42881
#  P99.9 Service Time Utilization (%) [GET-NoCache]     - 67.16339
#  P99.99 Service Time Utilization (%) [GET-NoCache]    - 138.86694
#  P99 Service Time Utilization (%) [PUT]               - 10.70621
#  P99.9 Service Time Utilization (%) [PUT]             - 13.09393
#  P99.99 Service Time Utilization (%) [PUT]            - 13.71510
#  P99 Service Time Saved ratio 1                       - 0.35719
#  P99.9 Service Time Saved ratio 1                     - 0.54263
#  P99.99 Service Time Saved ratio 1                    - 0.76494
#  Peak Service Time Saved ratio 1 (range)              - 0.77624
#  Peak Service Time Saved ratio 2 (1st M to end)       - 0.77516
#  Service Time Saved ratio 1 (range)                   - 0.27468
#  Service Time Saved ratio 2 (first miss to end)       - 0.27200
#  Service Time Saved ratio 3 (start to end)            - 0.26977
#  Service Time Saved ratio                             - 0.26977
#  Bonus STS beyond STS(A) (Assumed EA too short)       - 0.00000
#  Est Service Time Lost from late/readmits             - 0.03611
#  ST + late/readmits potential                         - 0.31079
#  Potential STS(Analysis) from Admitted Episodes       - 0.00000
#  Service Time Saved (Analysis @ -1.0MB/s, -1.0GB)     - -1.00000
#  Service Time Saved (Analysis @ -1.0MB/s)             - -1.00000
#  Potential ST Saved (PF) (Analysis) from Admitted Eps - 0.00
#  Wasted hits from late/readmits: 0 IOs, 172322 chunks
#  IOPS saved ratio                                     - 0.34584
#  IOPS saved ratio (Flash)                             - 0.3458
#  IOPS saved ratio (AdmitBuffer)                       - 0.0000
#  IOPS saved ratio (Partial)                           - 0.06836
#  IOPS saved ratio lost from late/readmits             - 0.00000
#  IOPS SR (Analysis) from Admitted Episodes            - 0.00000
#  IOPS SR (Analysis, ConstantThisEA)                   - -1.00000
#  GETs                                                 - 127305 / 127305
#      Saved                                            - 44027
#      Misses                                           - 83278
#      iops_requests/op/GET_TEMP                        - 31263
#      iops_requests/op/GET_PERM                        - 95897
#      iops_requests/op/GET_NOT_INIT                    - 145
#  GET (No Cache) ST                                    - 19.2%
#      service_time_nocache/op/GET_TEMP                 - 2.8%
#      service_time_nocache/op/GET_PERM                 - 16.4%
#      service_time_nocache/op/GET_NOT_INIT             - 0.0%
#  PUTs                                                 - 20489
#      puts_ios/op/PUT_TEMP                             - 8585
#      puts_ios/op/PUT_PERM                             - 11904
#  PUT ST                                               - 4.9%
#      service_time_writes/op/PUT_TEMP                  - 2.6%
#      service_time_writes/op/PUT_PERM                  - 2.3%
#  Episodes admitted                                    - 8690 (Analysis: -1)
#  Chunk hit ratio                                      - 0.23684
#  Chunk hit ratio (Flash)                              - 0.23684
#  Flash Cache Hit Rate                                 - 0.23684
#  Client Bandwidth [GET]                               - 640.37 MB/s
#  Backend Bandwidth [GET+PUT]                          - 683.67 MB/s
#  Backend Bandwidth [GET]                              - 489.11 MB/s
#  Backend Bandwidth [PUT]                              - 194.56 MB/s
#  Chunks Queried                                       - 3097546
#  Chunks Saved                                         - 708236
#  Chunks Fetched from Backend                          - 2365890
#  Flash writes                                         - 172322
#  Acceptance Ratio                                     - 0.07290
#  Flash write rate                                     - 35.62 MB/s
#  Writing Chunks from Admitted Episodes                - 0.0 MB/s (WR Ratio: 0.00)
#  Analysis Closest Write Rate                          - -1.00
#  Flash Wasted % of WR                                 - 0.40
#  Flash Wasted (by admit)                              -
#  Flash Wasted (by evict)                              -
#  Cache Size                                           - -1.00 GB (Analysis) vs 366.48 (Sim, 3002 items)
#  Flash Avg Eviction Age                               - (1562.5,1.8h)
#  Assumed Flash EA
#      Too Short/Bonus Hits                             - 0 (STSR: 0.00)
#      Too Long/Extra Writes                            - 0 (WRR: 0.00)
#  Flash Mean Time in System                            - (2513.8,2.9h)
#  Analysis Mean Time in System                         - -1
#  Time to warmup                                       - 1917, 1 hr 21 mins 10 secs
#  Simulator RAM usage                                  - 0.4 GB
#  Simulator Time                                       - 5 mins 47 secs
#
# Results written to runs/example/rejectx/rejectx-ap-1_0.508154_lru_366.475GB/full_0_0.1_cache_perf.txt.stats.lzma
# Results written to runs/example/rejectx/rejectx-ap-1_0.508154_lru_366.475GB/full_0_0.1_cache_perf.txt.lzma
# Command:
# /work/Baleen-FAST24-Artifact/Baleen-FAST24/BCacheSim/cachesim/../run_py.sh py /work/Baleen-FAST24-Artifact/Baleen-FAST24/BCacheSim/cachesim/simulate_ap.py --config runs/example/rejectx/config.json
# Removed file runs/example/rejectx/rejectx-ap-1_0.508154_lru_366.475GB/full_0_0.1_cache_perf.txt.part.lzma
# Removed file runs/example/rejectx/rejectx-ap-1_0.508154_lru_366.475GB/full_0_0.1_cache_perf.txt.stats.part.lzma
# Complete
# + exit
# ++ '[' 2 = 1 ']'

# %% [markdown]
# ### Train Baleen (3 mins)

# %%
./BCacheSim/run_py.sh py -B -m BCacheSim.episodic_analysis.train --exp example --policy PolicyUtilityServiceTimeSize2 --region Region1 --sample-ratio 0.1 --sample-start 0 --trace-group 201910 --supplied-ea physical --target-wrs 34 50 100 75 20 10 60 90 30 --target-csizes 366.475 --output-base-dir runs/example/baleen --eviction-age 5892.856 --rl-init-kwargs filter_=prefetch --train-target-wr 35.599 --train-models admit prefetch --train-split-secs-start 0 --train-split-secs-end 86400 --ap-acc-cutoff 15 --ap-feat-subset meta+block+chunk
# Out:
# + PYTHON=py
# + ARGS='-B -m BCacheSim.episodic_analysis.train --exp example --policy PolicyUtilityServiceTimeSize2 --region Region1 --sample-ratio 0.1 --sample-start 0 --trace-group 201910 --supplied-ea physical --target-wrs 34 50 100 75 20 10 60 90 30 --target-csizes 366.475 --output-base-dir runs/example/baleen --eviction-age 5892.856 --rl-init-kwargs filter_=prefetch --train-target-wr 35.599 --train-models admit prefetch --train-split-secs-start 0 --train-split-secs-end 86400 --ap-acc-cutoff 15 --ap-feat-subset meta+block+chunk'
# + case "$PYTHON" in
# + PYTHON_BIN=python
# +++ dirname ./BCacheSim/run_py.sh
# ++ cd ./BCacheSim
# ++ pwd
# + DIR=/work/Baleen-FAST24-Artifact/Baleen-FAST24/BCacheSim
# + cd /work/Baleen-FAST24-Artifact/Baleen-FAST24/BCacheSim/..
# + stdbuf -eL -oL python -B -m BCacheSim.episodic_analysis.train --exp example --policy PolicyUtilityServiceTimeSize2 --region Region1 --sample-ratio 0.1 --sample-start 0 --trace-group 201910 --supplied-ea physical --target-wrs 34 50 100 75 20 10 60 90 30 --target-csizes 366.475 --output-base-dir runs/example/baleen --eviction-age 5892.856 --rl-init-kwargs filter_=prefetch --train-target-wr 35.599 --train-models admit prefetch --train-split-secs-start 0 --train-split-secs-end 86400 --ap-acc-cutoff 15 --ap-feat-subset meta+block+chunk
# rl_init_kwargs: {'filter_': 'prefetch'}
# Sample cmd for debug:  --exp example --policy PolicyUtilityServiceTimeSize2 --region Region1 --sample-ratio 0.1 --sample-start 0.0 --trace-group 201910 --supplied-ea physical --target-wrs 34 50 100 75 20 10 60 90 30 --target-csizes 366.475 --output-base-dir runs/example/baleen --eviction-age 5892.86 --only-gets --rl-init-kwargs filter_=prefetch --train-target-wr 35.599 --train-models admit prefetch --no-episodes  --train-split-secs-start 0  --train-split-secs-end 86400
# Logging to tmp/example/201910_Region1_0_0.1/ea_5892.86_wr_35.599.out
# Cmd for rerun: bcachesimrun_py.sh py -B -m episodic_analysis.train --exp example --policy PolicyUtilityServiceTimeSize2 --region Region1 --sample-ratio 0.1 --sample-start 0 --trace-group 201910 --supplied-ea physical --target-wrs 34 50 100 75 20 10 60 90 30 --target-csizes 366.475 --output-base-dir runs/example/baleen --eviction-age 5892.856 --rl-init-kwargs filter_=prefetch --train-target-wr 35.599 --train-models admit prefetch --train-split-secs-start 0 --train-split-secs-end 86400 --ap-acc-cutoff 15 --ap-feat-subset meta+block+chunk
# Files to generate
# analysis runs/example/baleen/example/201910_Region1_0_0.1/offline_analysis_ea_5892.86.csv Exists
# thresholds tmp/example/201910_Region1_0_0.1/decisions_utility_service_time_size_fixed_ea_5892.86.pkl.bz Exists
# model_prefetch_offset_start tmp/example/201910_Region1_0_0.1/ea_5892.86_wr_35.599_prefetch_offset_start.model Exists
# model_prefetch_size tmp/example/201910_Region1_0_0.1/ea_5892.86_wr_35.599_prefetch_size.model Exists
# model_prefetch_offset_end tmp/example/201910_Region1_0_0.1/ea_5892.86_wr_35.599_prefetch_offset_end.model Exists
# model_prefetch_pred_net_pf_st_binary tmp/example/201910_Region1_0_0.1/ea_5892.86_wr_35.599_prefetch_pred_net_pf_st_binary.model Exists
# model_admit_threshold_binary tmp/example/201910_Region1_0_0.1/ea_5892.86_wr_35.599_admit_threshold_binary.model
# trace_kwargs: {'region': 'Region1', 'sample_ratio': 0.1, 'start': 0.0, 'trace_group': '201910', 'only_gets': True, 'min_ts_from_start': 0.0, 'max_ts_from_start': 86400.0, 'get_features': True}
# Reading from file data/tectonic/201910/Region1/full_0_0.1.trace
# Trace details: Duration=86401.23277902603, Start=1572074461.57806, End=1572160862.810839, NumAccesses=17987
# res_fn_kwargs: {'workers': 8, 'residency_fn': <function process_obj_chunk_n_noprefetch_w_accs at 0x7f7303148310>, 'residencylist_class': <class 'BCacheSim.episodic_analysis.episodes.ResidencyListPrefetchAware'>}
# gen_episodes: 100%|████████████████████████| 2848/2848 [00:22<00:00, 129.37it/s]
# tmp/example/201910_Region1_0_0.1/decisions_utility_service_time_size_fixed_ea_5892.86.pkl.bz already exists
# Primary targets only
#    Assumed Eviction Age (s)  Target Write Rate  Target Cache Size  Service Time Saved Ratio  IOPSSavedRatio  Write Rate (MB/s)  Cache Size (GB)  Mean Time In System (s)  Episodes admitted  Cutoff score      Target
# 0                  5892.856                NaN            366.475                   0.51475        0.581587          24.046243       366.666117             15614.335728                497      0.003161  Cache Size
# 0                  5892.856               34.0                NaN                   0.54420        0.613665          34.053334       456.093015             13714.934724                638      0.002127  Write Rate
# Others
#    Assumed Eviction Age (s)  Target Write Rate  Target Cache Size  Service Time Saved Ratio  IOPSSavedRatio  Write Rate (MB/s)  Cache Size (GB)  Mean Time In System (s)  Episodes admitted  Cutoff score                      Target
# 0                  5892.856                NaN            366.475                  0.514750        0.581587          24.046243       366.666117             15614.335728                497      0.003161                  Cache Size
# 0                  5892.856         295.827666                NaN                  0.645137        0.770890         295.827666      2084.838698              7216.616547               4121     -0.006925              Max Write Rate
# 0                  5892.856         154.763417                NaN                  0.645602        0.769055         154.763417      1273.019727              8422.999618               2030      0.000019   Max Write Rate (No waste)
# 0                  5892.856         295.827666                NaN                  0.645137        0.770890         295.827666      2084.838698              7216.616547               4121     -0.006925  Max Write Rate (Not empty)
# 0                  5892.856          34.000000                NaN                  0.544200        0.613665          34.053334       456.093015             13714.934724                638      0.002127                  Write Rate
# 1                  5892.856          50.000000                NaN                  0.578215        0.651804          50.038349       587.630633             12025.452194                832      0.001547                  Write Rate
# 2                  5892.856         100.000000                NaN                  0.630011        0.722299         100.002913       955.524962              9784.290550               1421      0.000539                  Write Rate
# 3                  5892.856          75.000000                NaN                  0.609445        0.683160          75.042332       788.781667             10763.423851               1140      0.001054                  Write Rate
# 4                  5892.856          20.000000                NaN                  0.499783        0.558959          20.037330       332.235623             16978.773163                425      0.004146                  Write Rate
# 5                  5892.856          10.000000                NaN                  0.440463        0.481070          10.007091       212.469931             21741.504011                254      0.008635                  Write Rate
# 6                  5892.856          60.000000                NaN                  0.592313        0.673264          60.055567       665.754937             11351.704634                970      0.001104                  Write Rate
# 7                  5892.856          90.000000                NaN                  0.624182        0.704342          90.072500       897.515557             10203.513120               1312      0.000585                  Write Rate
# 8                  5892.856          30.000000                NaN                  0.534164        0.599766          30.001019       422.732227             14428.770075                572      0.002595                  Write Rate
# Episode filter: prefetch
# #Episodes: 4121, #Accesses: 17987
# Training model for offset_start
# /home/wonglkd_globusid_org/.local/lib/python3.10/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/wonglkd_globusid_org/.local/lib/python3.10/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training model for size
# Training model for offset_end
#             MSE        R2  Threshold         Label Subset
# 0  7.821374e+11  0.500186        0.5  offset_start  Train
# 1  9.388968e+11  0.417361        0.5  offset_start   Test
# 2  3.914104e+12  0.685385        0.5          size  Train
# 3  4.817162e+12  0.638239        0.5          size   Test
# 4  3.238404e+12  0.715996        0.5    offset_end  Train
# 5  3.923970e+12  0.683815        0.5    offset_end   Test
# Training model for pred_net_pf_st_binary
# /home/wonglkd_globusid_org/.local/lib/python3.10/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/wonglkd_globusid_org/.local/lib/python3.10/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# Training model for pf_benefit
# Training model for pred_pf_benefit
# Training model for pred_net_pf_st
# /work/Baleen-FAST24-Artifact/Baleen-FAST24/BCacheSim/episodic_analysis/train_utils.py:20: RuntimeWarning: divide by zero encountered in scalar divide
#   ret['FN/FP'] = ret['FN'] / ret['FP']
# /work/Baleen-FAST24-Artifact/Baleen-FAST24/BCacheSim/episodic_analysis/train_utils.py:20: RuntimeWarning: divide by zero encountered in scalar divide
#   ret['FN/FP'] = ret['FN'] / ret['FP']
#             MSE        R2  Threshold  ...  TNR FN/FP  Accuracy
# 0  7.821374e+11  0.500186        0.5  ...  NaN   NaN       NaN
# 1  9.388968e+11  0.417361        0.5  ...  NaN   NaN       NaN
# 2  3.914104e+12  0.685385        0.5  ...  NaN   NaN       NaN
# 3  4.817162e+12  0.638239        0.5  ...  NaN   NaN       NaN
# 4  3.238404e+12  0.715996        0.5  ...  NaN   NaN       NaN
# 5  3.923970e+12  0.683815        0.5  ...  NaN   NaN       NaN
# 0  1.955743e-02  0.000000        0.5  ...  1.0   inf  0.980044
# 1  1.524496e-02 -0.001325        0.5  ...  1.0   inf  0.984536
# 2  2.148027e-03  0.647603        0.5  ...  NaN   NaN       NaN
# 3  2.896311e-03  0.573482        0.5  ...  NaN   NaN       NaN
# 4  2.479886e-05  0.089543        0.5  ...  NaN   NaN       NaN
# 5  8.868613e-06  0.090182        0.5  ...  NaN   NaN       NaN
# 6  4.809722e-05  0.291816        0.5  ...  NaN   NaN       NaN
# 7  5.485238e-05  0.196444        0.5  ...  NaN   NaN       NaN
#
# [14 rows x 13 columns]
# Source Episodes: 4121, Used Episodes: 4121
# Rows: 11227, Train: 7946, Test: 3281
# ./BCacheSim/run_py.sh: line 31:   604 Killed                  stdbuf -eL -oL $PYTHON_BIN $ARGS
# : 137

# %%
./BCacheSim/run_py.sh py -B -m BCacheSim.episodic_analysis.train --exp example --policy PolicyUtilityServiceTimeSize2 --region Region1 --sample-ratio 0.1 --sample-start 0 --trace-group 201910 --supplied-ea physical --target-wrs 34 50 100 75 20 10 60 90 30 --target-csizes 366.475 --output-base-dir runs/example/baleen --eviction-age 5892.856 --rl-init-kwargs filter_=prefetch --train-target-wr 35.599 --train-models admit --train-split-secs-start 0 --train-split-secs-end 86400 --ap-acc-cutoff 15 --ap-feat-subset meta+block+chunk
# Out:
# + PYTHON=py
# + ARGS='-B -m BCacheSim.episodic_analysis.train --exp example --policy PolicyUtilityServiceTimeSize2 --region Region1 --sample-ratio 0.1 --sample-start 0 --trace-group 201910 --supplied-ea physical --target-wrs 34 50 100 75 20 10 60 90 30 --target-csizes 366.475 --output-base-dir runs/example/baleen --eviction-age 5892.856 --rl-init-kwargs filter_=prefetch --train-target-wr 35.599 --train-models admit --train-split-secs-start 0 --train-split-secs-end 86400 --ap-acc-cutoff 15 --ap-feat-subset meta+block+chunk'
# + case "$PYTHON" in
# + PYTHON_BIN=python
# +++ dirname ./BCacheSim/run_py.sh
# ++ cd ./BCacheSim
# ++ pwd
# + DIR=/work/Baleen-FAST24-Artifact/Baleen-FAST24/BCacheSim
# + cd /work/Baleen-FAST24-Artifact/Baleen-FAST24/BCacheSim/..
# + stdbuf -eL -oL python -B -m BCacheSim.episodic_analysis.train --exp example --policy PolicyUtilityServiceTimeSize2 --region Region1 --sample-ratio 0.1 --sample-start 0 --trace-group 201910 --supplied-ea physical --target-wrs 34 50 100 75 20 10 60 90 30 --target-csizes 366.475 --output-base-dir runs/example/baleen --eviction-age 5892.856 --rl-init-kwargs filter_=prefetch --train-target-wr 35.599 --train-models admit --train-split-secs-start 0 --train-split-secs-end 86400 --ap-acc-cutoff 15 --ap-feat-subset meta+block+chunk
# rl_init_kwargs: {'filter_': 'prefetch'}
# Sample cmd for debug:  --exp example --policy PolicyUtilityServiceTimeSize2 --region Region1 --sample-ratio 0.1 --sample-start 0.0 --trace-group 201910 --supplied-ea physical --target-wrs 34 50 100 75 20 10 60 90 30 --target-csizes 366.475 --output-base-dir runs/example/baleen --eviction-age 5892.86 --only-gets --rl-init-kwargs filter_=prefetch --train-target-wr 35.599 --train-models admit --no-episodes  --train-split-secs-start 0  --train-split-secs-end 86400
# Logging to tmp/example/201910_Region1_0_0.1/ea_5892.86_wr_35.599.out
# Cmd for rerun: bcachesimrun_py.sh py -B -m episodic_analysis.train --exp example --policy PolicyUtilityServiceTimeSize2 --region Region1 --sample-ratio 0.1 --sample-start 0 --trace-group 201910 --supplied-ea physical --target-wrs 34 50 100 75 20 10 60 90 30 --target-csizes 366.475 --output-base-dir runs/example/baleen --eviction-age 5892.856 --rl-init-kwargs filter_=prefetch --train-target-wr 35.599 --train-models admit --train-split-secs-start 0 --train-split-secs-end 86400 --ap-acc-cutoff 15 --ap-feat-subset meta+block+chunk
# Files to generate
# analysis runs/example/baleen/example/201910_Region1_0_0.1/offline_analysis_ea_5892.86.csv Exists
# thresholds tmp/example/201910_Region1_0_0.1/decisions_utility_service_time_size_fixed_ea_5892.86.pkl.bz Exists
# model_admit_threshold_binary tmp/example/201910_Region1_0_0.1/ea_5892.86_wr_35.599_admit_threshold_binary.model
# trace_kwargs: {'region': 'Region1', 'sample_ratio': 0.1, 'start': 0.0, 'trace_group': '201910', 'only_gets': True, 'min_ts_from_start': 0.0, 'max_ts_from_start': 86400.0, 'get_features': True}
# Reading from file data/tectonic/201910/Region1/full_0_0.1.trace
# Trace details: Duration=86401.23277902603, Start=1572074461.57806, End=1572160862.810839, NumAccesses=17987
# res_fn_kwargs: {'workers': 8, 'residency_fn': <function process_obj_chunk_n_noprefetch_w_accs at 0x7f7292dec310>, 'residencylist_class': <class 'BCacheSim.episodic_analysis.episodes.ResidencyListPrefetchAware'>}
# gen_episodes: 100%|████████████████████████| 2848/2848 [00:23<00:00, 120.67it/s]
# tmp/example/201910_Region1_0_0.1/decisions_utility_service_time_size_fixed_ea_5892.86.pkl.bz already exists
# Primary targets only
#    Assumed Eviction Age (s)  Target Write Rate  Target Cache Size  Service Time Saved Ratio  IOPSSavedRatio  Write Rate (MB/s)  Cache Size (GB)  Mean Time In System (s)  Episodes admitted  Cutoff score      Target
# 0                  5892.856                NaN            366.475                  0.515065        0.581753          24.138834       367.027391             15569.768264                498      0.003161  Cache Size
# 0                  5892.856               34.0                NaN                  0.544200        0.613665          34.053334       456.093015             13714.934724                638      0.002127  Write Rate
# Others
#    Assumed Eviction Age (s)  Target Write Rate  Target Cache Size  Service Time Saved Ratio  IOPSSavedRatio  Write Rate (MB/s)  Cache Size (GB)  Mean Time In System (s)  Episodes admitted  Cutoff score                      Target
# 0                  5892.856                NaN            366.475                  0.515065        0.581753          24.138834       367.027391             15569.768264                498      0.003161                  Cache Size
# 0                  5892.856         295.827666                NaN                  0.645137        0.770890         295.827666      2084.838698              7216.616547               4121     -0.006925              Max Write Rate
# 0                  5892.856         154.763417                NaN                  0.645602        0.769055         154.763417      1273.019727              8422.999618               2030      0.000019   Max Write Rate (No waste)
# 0                  5892.856         295.827666                NaN                  0.645137        0.770890         295.827666      2084.838698              7216.616547               4121     -0.006925  Max Write Rate (Not empty)
# 0                  5892.856          34.000000                NaN                  0.544200        0.613665          34.053334       456.093015             13714.934724                638      0.002127                  Write Rate
# 1                  5892.856          50.000000                NaN                  0.578253        0.651915          50.061496       588.382074             12035.262371                834      0.001547                  Write Rate
# 2                  5892.856         100.000000                NaN                  0.630011        0.722299         100.002913       955.671769              9785.793814               1421      0.000539                  Write Rate
# 3                  5892.856          75.000000                NaN                  0.609445        0.683160          75.042332       788.755172             10763.062312               1140      0.001054                  Write Rate
# 4                  5892.856          20.000000                NaN                  0.499783        0.558959          20.037330       332.235623             16978.773163                425      0.004146                  Write Rate
# 5                  5892.856          10.000000                NaN                  0.440463        0.481070          10.007091       212.469931             21741.504011                254      0.008635                  Write Rate
# 6                  5892.856          60.000000                NaN                  0.592313        0.673264          60.055567       665.483812             11347.081731                970      0.001104                  Write Rate
# 7                  5892.856          90.000000                NaN                  0.624182        0.704342          90.072500       897.515557             10203.513120               1312      0.000585                  Write Rate
# 8                  5892.856          30.000000                NaN                  0.534164        0.599766          30.001019       422.732227             14428.770075                572      0.002595                  Write Rate
# Episode filter: prefetch
# #Episodes: 4121, #Accesses: 17987
# Source Episodes: 4121, Used Episodes: 4121
# Rows: 11227, Train: 7908, Test: 3319
# ./BCacheSim/run_py.sh: line 31:   674 Killed                  stdbuf -eL -oL $PYTHON_BIN $ARGS
# : 137

# %%
ls tmp/example/201910_Region1_0_0.1
# Out:
# decisions_utility_service_time_size_fixed_ea_5892.86.pkl.bz
# ea_5892.86_wr_35.599.err
# ea_5892.86_wr_35.599.out
# ea_5892.86_wr_35.599_prefetch_offset_end.model
# ea_5892.86_wr_35.599_prefetch_offset_start.model
# ea_5892.86_wr_35.599_prefetch_pred_net_pf_st_binary.model
# ea_5892.86_wr_35.599_prefetch_size.model

# %% [markdown]
# ## Run Baleen in simulation (30 mins)

# %%
./BCacheSim/run_py.sh py -B -m BCacheSim.cachesim.simulate_ap --config runs/example/baleen/prefetch_ml-on-partial-hit/config.json
# Out:
# + PYTHON=py
# + ARGS='-B -m BCacheSim.cachesim.simulate_ap --config runs/example/baleen/prefetch_ml-on-partial-hit/config.json'
# + case "$PYTHON" in
# + PYTHON_BIN=python
# +++ dirname ./BCacheSim/run_py.sh
# ++ cd ./BCacheSim
# ++ pwd
# + DIR=/work/Baleen-FAST24-Artifact/Baleen-FAST24/BCacheSim
# + cd /work/Baleen-FAST24-Artifact/Baleen-FAST24/BCacheSim/..
# + stdbuf -eL -oL python -B -m BCacheSim.cachesim.simulate_ap --config runs/example/baleen/prefetch_ml-on-partial-hit/config.json
# {'admit_only_prefetches': False,
#  'ap': 'mlnew',
#  'ap_chunk_threshold': None,
#  'ap_feat_subset': 'meta+block+chunk',
#  'ap_probability': None,
#  'ap_threshold': 0.798545,
#  'batch_size': 16,
#  'block_level': False,
#  'cache_elems': None,
#  'cachelib_trace': None,
#  'coinflip_ap': False,
#  'config': ['runs/example/baleen/prefetch_ml-on-partial-hit/config.json'],
#  'debug': False,
#  'early_evict': None,
#  'ep_analysis': 'runs/example/baleen/example/201910_Region1_0_0.1/offline_analysis_ea_5892.86.csv',
#  'evict_by_episode': False,
#  'eviction_policy': 'LRU',
#  'fast': False,
#  'fifo': False,
#  'flashieldprob_ap_min_hits': None,
#  'flip_threshold': True,
#  'hybrid_ap_threshold': None,
#  'ignore_existing': False,
#  'job_id': None,
#  'learned_ap': True,
#  'learned_ap_filter_count': 6,
#  'learned_ap_granularity': 'both',
#  'learned_ap_model_path': 'tmp/example/201910_Region1_0_0.1/ea_5892.86_wr_35.599_admit_threshold_binary.model',
#  'learned_size': False,
#  'limit': None,
#  'lirs': False,
#  'log_decisions': False,
#  'log_episodes': False,
#  'log_evictions': False,
#  'log_interval': 600.0,
#  'log_prefetch': False,
#  'log_req': False,
#  'offline_ap': False,
#  'offline_ap_decisions': None,
#  'one_chunk': False,
#  'opt_ap_threshold': None,
#  'optplus_args': None,
#  'output_dir': 'runs/example/baleen/prefetch_ml-on-partial-hit',
#  'override': False,
#  'peak_strategy': None,
#  'prefetch': None,
#  'prefetch_range': 'acctime-episode-predict',
#  'prefetch_when': 'partial',
#  'prefetch_when_threshold': None,
#  'prefetcher_model_path': 'tmp/example/201910_Region1_0_0.1/ea_5892.86_wr_35.599_prefetch_{k}.model',
#  'profile': False,
#  'ram_ap_clone': False,
#  'ram_cache': False,
#  'ram_cache_elems': None,
#  'ram_cache_size_gb': 10.0,
#  'rejectx_ap': False,
#  'rejectx_ap_factor': None,
#  'rejectx_ap_threshold': None,
#  'retrain_interval_hrs': None,
#  'size_gb': 366.475,
#  'size_opt': 'access',
#  'stats_start': 86400.0,
#  'trace': 'data/tectonic/201910/Region1/full_0_0.1.trace',
#  'tracefile': 'data/tectonic/201910/Region1/full_0_0.1.trace',
#  'train_history_hrs': None,
#  'ttl_model_path': None,
#  'write_mbps': 0}
# Command: /work/Baleen-FAST24-Artifact/Baleen-FAST24/BCacheSim/cachesim/../run_py.sh py /work/Baleen-FAST24-Artifact/Baleen-FAST24/BCacheSim/cachesim/simulate_ap.py --config runs/example/baleen/prefetch_ml-on-partial-hit/config.json
# Output dir: runs/example/baleen/prefetch_ml-on-partial-hit/ml-ap-0.798545_6_lru_366.475GB
# Logging to runs/example/baleen/prefetch_ml-on-partial-hit/ml-ap-0.798545_6_lru_366.475GB/full_0_0.1.out
# [LightGBM] [Fatal] Could not open tmp/example/201910_Region1_0_0.1/ea_5892.86_wr_35.599_admit_threshold_binary.model
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/opt/conda/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/work/Baleen-FAST24-Artifact/Baleen-FAST24/BCacheSim/cachesim/simulate_ap.py", line 183, in <module>
#     sim_cache.simulate_cache_driver(get_parsed_args())
#   File "/work/Baleen-FAST24-Artifact/Baleen-FAST24/BCacheSim/cachesim/sim_cache.py", line 1480, in simulate_cache_driver
#     ap = aps.construct(
#   File "/work/Baleen-FAST24-Artifact/Baleen-FAST24/BCacheSim/cachesim/admission_policies.py", line 974, in construct
#     ap = NewMLAP(threshold, model_path=options.learned_ap_model_path, **kwargs_)
#   File "/work/Baleen-FAST24-Artifact/Baleen-FAST24/BCacheSim/cachesim/admission_policies.py", line 349, in __init__
#     super().__init__(*args, **kwargs)
#   File "/work/Baleen-FAST24-Artifact/Baleen-FAST24/BCacheSim/cachesim/admission_policies.py", line 294, in __init__
#     self.gbm = lgb.Booster(model_file=model_path)
#   File "/home/wonglkd_globusid_org/.local/lib/python3.10/site-packages/lightgbm/basic.py", line 2639, in __init__
#     _safe_call(_LIB.LGBM_BoosterCreateFromModelfile(
#   File "/home/wonglkd_globusid_org/.local/lib/python3.10/site-packages/lightgbm/basic.py", line 125, in _safe_call
#     raise LightGBMError(_LIB.LGBM_GetLastError().decode('utf-8'))
# lightgbm.basic.LightGBMError: Could not open tmp/example/201910_Region1_0_0.1/ea_5892.86_wr_35.599_admit_threshold_binary.model
# : 1

# %% [markdown]
# ### To examine the results, run [Baleen-FAST24/notebooks/example/example.ipynb](Baleen-FAST24/notebooks/example/example.ipynb)
